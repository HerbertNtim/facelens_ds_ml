# %%
# Import libraries
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.svm import SVC
from sklearn import metrics

# %%
# Load data
faces_data = np.load('../save_data/data_pca_50_target.npz')
faces_data.files
# Out:
# ['arr_0', 'arr_1']

# %%
faces_data.allow_pickle = True

# %%
X = faces_data['arr_0'] # pca data
y = faces_data['arr_1'] # target or dependent variable

# %%
X.shape, y.shape
# Out:
# ((5053, 50), (5053,))

# %%
X
# Out:
# array([[ 0.89019399,  0.40990359, -0.34663686, ..., -0.12323515,
#         -0.43250683, -0.68092706],
#        [ 0.97238295,  0.83355577,  1.02477613, ..., -0.4288611 ,
#          1.34738417, -0.65569524],
#        [-0.06763602,  1.32564429, -1.22991725, ..., -1.89907194,
#          1.3875824 ,  1.21204898],
#        ...,
#        [ 1.13192769,  1.00478845, -0.10043763, ..., -0.8620564 ,
#          0.7919071 ,  0.93206986],
#        [-0.42987774,  1.0165436 ,  1.44119154, ..., -1.73152651,
#          2.99843834,  1.75941892],
#        [-0.29601157,  0.7408302 ,  0.11640472, ..., -1.59227157,
#          0.67237367,  0.20608825]], shape=(5053, 50))

# %%
y
# Out:
# array(['female', 'female', 'female', ..., 'male', 'male', 'male'],
#       shape=(5053,), dtype=object)

# %% [markdown]
# # Split the data into Training and Testing

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((4042, 50), (1011, 50), (4042,), (1011,))

# %% [markdown]
# ### Training Machine Learning Model
